# %%
# !pip install plotly==4.1.0
# Out:
# Collecting plotly==4.1.0
#   Downloading plotly-4.1.0-py2.py3-none-any.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 165 kB/s eta 0:00:011
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in /home/psalms116/Documents/Dev/anaconda3/envs/e-02-form-ml/lib/python3.9/site-packages (from plotly==4.1.0) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=d22429a9d5c1f1208fee8ebe5257370f751ae660c0cba3f8a29ecba79dca6436
#   Stored in directory: /home/psalms116/.cache/pip/wheels/ce/18/7f/e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.1.0 retrying-1.3.3

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# %%
caminho_arquivo = "Wine.csv"
df = pd.read_csv(caminho_arquivo) #importando os dados

# %%
print("O dado possui",df.shape[0], "amostras e", df.shape[1], "atributos")
# Out:
# O dado possui 178 amostras e 14 atributos

# %%
colunas = df.columns
print(*(' - '+colunas), sep='\n')
# Out:
#  - Alcool
#  - Acido_malico
#  - Po
#  - Alcalinidade_po
#  - Magnesio
#  - Total_Fenois
#  - Flavanoides
#  - Fenois_nao_flavalonoides
#  - Proanthocyanins
#  - Intensidade_de_cor
#  - Matiz_de_cores
#  - OD280
#  - Proline

# %%
df.head()
# Out:
#    Alcool  Acido_malico    Po  Alcalinidade_po  Magnesio  Total_Fenois  \
# 0   14.23          1.71  2.43             15.6       127          2.80
# 1   13.20          1.78  2.14             11.2       100          2.65
# 2   13.16          2.36  2.67             18.6       101          2.80
# 3   14.37          1.95  2.50             16.8       113          3.85
# 4   13.24          2.59  2.87             21.0       118          2.80
#
#    Flavanoides  Fenois_nao_flavalonoides  Proanthocyanins  Intensidade_de_cor  \
# 0         3.06                      0.28             2.29                5.64
# 1         2.76                      0.26             1.28                4.38
# 2         3.24                      0.30             2.81                5.68
# 3         3.49                      0.24             2.18                7.80
# 4         2.69                      0.39             1.82                4.32
#
#    Matiz_de_cores  OD280  Proline
# 0            1.04   3.92     1065
# 1            1.05   3.40     1050
# 2            1.03   3.17     1185
# 3            0.86   3.45     1480
# 4            1.04   2.93      735

# %%
labels_df = df['Customer_Segment']
df = df.drop(columns = 'Customer_Segment')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/Dev/anaconda3/envs/e-02-form-ml/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer_Segment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-bef1673a690d> in <module>
# ----> 1 labels_df = df['Customer_Segment']
#       2 df = df.drop(columns = 'Customer_Segment')
#       3 df.head()
#
# ~/Documents/Dev/anaconda3/envs/e-02-form-ml/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/Documents/Dev/anaconda3/envs/e-02-form-ml/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Customer_Segment'

# %%
df = df.rename(columns = {'Alcohol'              : 'Alcool', 
                          'Malic_Acid'           : 'Acido_malico',
                          'Ash'                  : 'Po', 
                          'Ash_Alcanity'         : 'Alcalinidade_po',
                          'Magnesium'            : 'Magnesio',
                          'Total_Phenols'        : 'Total_Fenois',
                          'Flavanoids'           : 'Flavanoides',
                          'Nonflavanoid_Phenols' :'Fenois_nao_flavalonoides',   
                          'Color_Intensity'      :'Intensidade_de_cor',
                          'Hue'                  : 'Matiz_de_cores'})

# %%
# CONTINUAR DAQUI. Ver a partir do vídeo. Retirar o que não precisar.
# De preferência, evitar biokit.

# %%
# !pip install biokit

# %%
from biokit.viz import corrplot
import matplotlib.pyplot as plt

# %%
# ANTES
# import matplotlib
# matplotlib.__version__
# '3.3.4'

# %%
# !pip install matplotlib==3.2.2

# Para evitar erro: AttributeError: 'Colorbar' object has no attribute 'set_clim'

# %%
# DEPOIS
import matplotlib
matplotlib.__version__
# '3.2.2'
# Out:
# '3.2.2'

# %%
matriz_corr = df.corr()

# %%
corr_graf = corrplot.Corrplot(matriz_corr)

corr_graf.plot(upper = 'ellipse', 
               fontsize = 'x-large', 
               grid=True)
# Out:
# /home/psalms116/Documents/Dev/anaconda3/envs/e-02-form-ml/lib/python3.9/site-packages/biokit/viz/corrplot.py:335: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   cb.set_clim(0,1) # make sure it goes from -1 to 1 even though actual values may not reach that range

# %%
fig = plt.gcf()
fig.set_size_inches(13,8)
fig.show()
# Out:
# <ipython-input-15-6430b57f0a5f>:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
np_df = min_max_scaler.fit_transform(df)

# %%
df = pd.DataFrame(np_df, columns = colunas)

# %%
df.describe()
# Out:
#            Alcool  Malic_Acid          Po  Ash_Alcanity    Magnesio  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean     0.518584    0.315484    0.538244      0.458502    0.323278
# std      0.213639    0.220780    0.146708      0.172142    0.155244
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%      0.350658    0.170455    0.454545      0.340206    0.195652
# 50%      0.531579    0.222332    0.534759      0.458763    0.304348
# 75%      0.696711    0.462945    0.640374      0.561856    0.402174
# max      1.000000    1.000000    1.000000      1.000000    1.000000
#
#        Total_Fenois  Flavanoids  Fenois_nao_flavalonoides  Proanthocyanins  \
# count    178.000000  178.000000                178.000000       178.000000
# mean       0.453487    0.356386                  0.437460         0.372523
# std        0.215811    0.210730                  0.234818         0.180555
# min        0.000000    0.000000                  0.000000         0.000000
# 25%        0.262931    0.182489                  0.264151         0.264984
# 50%        0.474138    0.378692                  0.396226         0.361199
# 75%        0.627586    0.534810                  0.580189         0.485804
# max        1.000000    1.000000                  1.000000         1.000000
#
#        Intensidade_de_cor         Hue       OD280     Proline
# count          178.000000  178.000000  178.000000  178.000000
# mean             0.322363    0.388170    0.491460    0.334446
# std              0.197806    0.185831    0.260070    0.224613
# min              0.000000    0.000000    0.000000    0.000000
# 25%              0.165529    0.245935    0.244505    0.158702
# 50%              0.290956    0.394309    0.553114    0.282097
# 75%              0.419795    0.520325    0.695971    0.504280
# max              1.000000    1.000000    1.000000    1.000000

# %%
np_df = min_max_scaler.inverse_transform(df)

# %%
df_nao_normalizado = pd.DataFrame(np_df, columns = colunas)
df_nao_normalizado.describe()
# Out:
#            Alcool  Malic_Acid          Po  Ash_Alcanity    Magnesio  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Fenois  Flavanoids  Fenois_nao_flavalonoides  Proanthocyanins  \
# count    178.000000  178.000000                178.000000       178.000000
# mean       2.295112    2.029270                  0.361854         1.590899
# std        0.625851    0.998859                  0.124453         0.572359
# min        0.980000    0.340000                  0.130000         0.410000
# 25%        1.742500    1.205000                  0.270000         1.250000
# 50%        2.355000    2.135000                  0.340000         1.555000
# 75%        2.800000    2.875000                  0.437500         1.950000
# max        3.880000    5.080000                  0.660000         3.580000
#
#        Intensidade_de_cor         Hue       OD280      Proline
# count          178.000000  178.000000  178.000000   178.000000
# mean             5.058090    0.957449    2.611685   746.893258
# std              2.318286    0.228572    0.709990   314.907474
# min              1.280000    0.480000    1.270000   278.000000
# 25%              3.220000    0.782500    1.937500   500.500000
# 50%              4.690000    0.965000    2.780000   673.500000
# 75%              6.200000    1.120000    3.170000   985.000000
# max             13.000000    1.710000    4.000000  1680.000000
